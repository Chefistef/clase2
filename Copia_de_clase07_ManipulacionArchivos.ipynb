# %% [markdown]
# <a href="https://colab.research.google.com/github/Chefistef/clase2/blob/master/Copia_de_clase07_ManipulacionArchivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 07

# %% [markdown]
# # Manipulación de archivos

# %% [markdown]
# En la última década se ha incrementado las fuentes desde las que se puede obtener y desplegar información (datos) que un sistema informatico consume, gestiona y genera. En Python existe una gran variedad de métodos para presentar la salida de datos, los cuales pueden ser impresos de manera legible para los humanos, o escritos a un archivo para su uso futuro. En este capítulo se tratará algunas de las posibilidades.

# %% [markdown]
# ## Función open()
#
# Antes de leer o escribir en un archivo, hay que abrirlo utilizando la función open() . Esta función crea un objeto file que se utiliza para llamar a otros métodos de apoyo asociados con ella.
#
# Sintaxis:
#
# archivo = open(Nombre_archivo ,< Modo Apertura>, < Buffer>)
#
# **Nombre_archivo:** El argumento Nombre_archivo es un valor de cadena que contiene el nombre del archivo que se desea acceder.
#
# **Modo_apertura:** Determina el modo en el que el archivo tiene que ser abierto, es decir, leer, escribir, añadir, etc. Este es un parámetro opcional y se lee el modo de acceso de archivos por defecto (r).
#
# **Búfer:** determina el tamaño del buffer indicado.

# %% [markdown]
# | Modos | Descripción |
# |------|------|
# |  **r**  | Abre un archivo de sólo lectura. Este es el modo por defecto. |
# |  **rb**  | Abre un archivo de sólo lectura en formato binario. |
# |  **r+**  | Abre un archivo en modo de lectura y escritura. |
# |  **rb+**  | Abre un archivo para lectura y escritura en formato binario. |
# |  **w**  | Abre un archivo para sólo escritura. Sobrescribe el archivo si existe. Si no existe el archivo, crea un nuevo archivo para escritura. |
# |  **wb**  | Abre un archivo para escribir en formato binario. Sobrescribe el archivo si existe. Si no existe el archivo, crea un nuevo archivo para escritura. |
# |  **w+**  | Abre un archivo para escritura y lectura. Sobrescribe el archivo existente. Si no existe el archivo, crea un nuevo archivo para la lectura y la escritura. |
# |  **WB+** | Abre un archivo para escritura y lectura en formato binario. Sobrescribe el archivo existente. Si no existe el archivo, crea uno nuevo. |
# |  **un**  | Abre un archivo para anexar. Si no existe el archivo, se crea un nuevo archivo para escritura. |
# |  **ab**  | Abre un archivo para anexar en formato binario. Si no existe el archivo, se crea un nuevo archivo para escritura. |
# |  **a+**  | Abre un archivo tanto para anexar y lectura. Si no existe el archivo, se crea un nuevo archivo para la lectura y la escritura. |
# |  **ab+** | Abre un archivo tanto para anexar y la lectura en formato binario. Si no existe el archivo, se crea un nuevo archivo para la lectura y la escritura. |

# %%
a = open("prueba.text", "w")

# %%
a.close()

# %%
b = open("prueba2.txt", "w")
b.write("hola mundo\n")
b.write("Adios mundo\n")
b.write("Hola mundo\n")
b.close()

# %% [markdown]
# ### Atributos del objeto File
#
# Una vez que se abre un archivo, se puede obtener diversa información relacionada con ese archivo. Aquí está una lista de algunos atributos relacionados con el objeto File:
#
#
#
# | Atributo | Descripción |
# |------|------|
# |  **file.closed**  | Devuelve true si el archivo está cerrado, falso en caso que este abierto. |
# |  **file.mode**  | Devuelve el modo de acceso con el que se abrió el objeto. |
# |  **file.name**  | Devuelve el nombre del archivo. |

# %%
archivo = open("prueba.txt", "wb")
print("Nombre archivo: "+ archivo)

# %%
print("Esta cerrado?" + str(archivo.closed))

# %%
print("Modo de apertura: " + archivo.mode)

# %%
archivo.close()

# %%
print("Esta cerrado?" + str(archivo.closed))

# %% [markdown]
# Se puede apreciar en el código fuente como que después de ejecutar el método close, se cierra el puntero que estaba sobre el archivo.

# %% [markdown]
# ## Lectura y escritura de archivos
#
# El objeto de File proporciona un conjunto de métodos de acceso para hacernos la vida más fácil. En los siguientes ejemplo vamos a utilizar los métodos  read () y write () para leer y escribir archivos.

# %% [markdown]
# ### Método write()
#
# El método de write () escribe cualquier tipo de cadena en un archivo abierto. Es importante tener en cuenta que las cadenas en Python pueden tener datos binarios y no sólo de texto. El método de write() no añade saltos de linea **\ n** al final de la cadena, por lo que tendremos que agregarlo nosotros en el código:

# %%
archivo = open("prueba.txt", "wb")

# %%
archivo.write("www.python.org\n")
archivo.write("www.google.com\n")
archivo.write("www.gmail.com\n")
archivo.close()

# %% [markdown]
# En el ejemplo agregamos 3 host al archivo prueba.txt

# %% [markdown]
# ### Método read ()
#
# El método de read () lee una cadena de un archivo abierto. Es importante tener en cuenta que las cadenas en Python pueden tener datos binarios. Además de los datos de texto.

# %%
archivo = open("prueba.txt", "r")
contenido = archivo.read()
print(contenido)

# %% [markdown]
# En la línea 1 abrimos en modo lectura (r) el archivo que ya estaba escrito por el ejemplo anterior y utilizamos el método read() para traernos el contenido.
#
# En la línea 1 abrimos en modo lectura (r) el archivo que ya estaba escrito por el ejemplo anterior y utilizamos el método read() para traernos el contenido.

# %%
archivo = open("prueba.txt", "wb")
archivo.write("www.python.org\n")
archivo.write("www.google.com\n")
archivo.write("www.gmail.com\n")
archivo.close()

archivo.open("prueba.txt", "r")
for lista in archivo.readlines():
    print(lista)

# %% [markdown]
# En Python desde la versión 2.5 adelante, nos entrega una forma más fácil de leer archivos con la palabra reservada with.

# %%
with open("prueba.txt", "r") as archivo:
    print(archivo.read())

# %% [markdown]
# En el código fuente se puede apreciar que en pocas líneas de código leemos un objeto file y el mismo interprete se encarga de cerrar el archivo evitándonos utilizar el método close()

# %% [markdown]
# # Archivos JSON

# %% [markdown]
# El formato **JSON (JavaScript Object Notation)** es comúnmente utilizado para la transferencia de datos por la red, es un formato simple y muy utilizado en todo tipo de aplicaciones web para el intercambio de datos entre el cliente y el servidor de datos.
#
# Utilizar el formato JSON en Python es muy fácil con el módulo json el cual cuenta con sus dos funciones principales, **json.dumps()** y **json.loads()**, para crear y cargar una estructura de datos en formato JSON.

# %% [markdown]
# ## Python a JSON
#
# Python hace que sea sencillo trabajar con archivos JSON. El módulo utilizado para este propósito es el módulo json. Este módulo debe ser incluido (built-in) dentro de tu instalación Python y, por lo tanto, no será necesario instalar módulos externos como se tendría que hacer para trabajar con archivos PDF y Excel, por ejemplo. Lo único que necesitas hacer con el fin de utilizar este módulo es importarlo:

# %%
import json

datos = {
    'nombre' : 'Roy Yali',
    'edad'   : 25,
    'pais'   : 'Perú'
}

json_str = json.dumps(datos)

# %% [markdown]
# Si deseas ver la salida, haz un print json_str. Si todo ha salido bien obtendrás el siguiente resultado:

# %%
print('Datos en formato JSON:', json_str)
# Out:
# {'age': 39, 'name': 'Frank'}

# %% [markdown]
# Es decir, los datos se devuelven como si fuese un diccionario de Python. Por lo tanto, la declaración print json_str["name"], ¿devolverá algo? Inténtalo...

# %% [markdown]
# ## JSON a Python
#
# Leer JSON significa convertir el JSON en un valor de Python (objeto). Como hemos mencionado anteriormente, la librería json parsea el JSON en un diccionario o en una lista en Python. Con el fin de hacer eso, utilizamos la función loads(), de la siguiente manera:

# %%
str_json = """
    {
        "nombre": "Juan Perez",
        "edad": 18,
        "pais": "Panama"
    }
"""

json_dat = json.loads(str_json);

# %%
print("Objeto tipo diccionario:", json_dat)
# Out:
# Objeto tipo diccionario: {'nombre': 'Juan Perez', 'edad': 18, 'pais': 'Panama'}

# %% [markdown]
# ## Leer o guardar un archivo en formato JSON

# %% [markdown]
# Cuando deseemos leer o guardar un archivo en formato JSON usaremos las funciones dump() y load() nótese que son diferentes a las anteriores, estas no terminan en “s”.
#
# Primero veamos como escribir un archivo en formato JSON, debemos indicarle a la función cuales son los datos que deseamos guardar y el archivo en el que lo haremos.

# %%
import json

datos = {
    'nombre' : 'Juan Perez',
    'edad'   : 18,
    'pais'   : 'Panama'
}

with open('datos.json', 'w') as file:
    json.dump(datos, file)

# %% [markdown]
# De modo similar leemos el archivo datos.json que acabamos de crear.

# %%
with open('datos.json', 'r') as file:
    data = json.load(file)
    print(data)

# %%
import jason

e = open("datopolygon.json", "r")
data = e.read()
print(type(data))
e.close()

# %%
dicc = {
    "apellido": "Muñoz",
    "curso": "Progra"
}
tex = json.dumps(dicc)
type(text)

# %%
d = open("students.json", "r")
data = d.read()
d.close()

print(type(data))
# Out:
# <class 'str'>

# %% [markdown]
# convierto a diccionario

# %%
s = json.loads(data)
print(type(s))
# Out:
# <class 'dict'>

# %% [markdown]
# ya es un diccionario y ahora tiene la funcionalidad de values, view

# %%
s.values()
# Out:
# dict_values([{'view': {'id': 'es3k-2aus', 'name': 'Student Weight Status Category Reporting Results: Beginning 2010', 'attribution': 'New York State Department of Health', 'attributionLink': 'http://www.health.ny.gov/prevention/obesity/', 'averageRating': 0, 'category': 'Health', 'createdAt': 1363701898, 'description': 'The Student Weight Status Category Reporting System (SWSCR) collects weight status category data (underweight, healthy weight, overweight or obese, based on BMI-for-age percentile).  The dataset includes separate estimates of the percent of students overweight, obese and overweight or obese for all reportable grades within the county and/or region and by grade groups (elementary and middle/high).   The rates of overweight and obesity reported are percentages based on counts of students in selected grades (Pre-K, K, 2, 4, 7, 10) reported to the NYSDOH. Because these rates reflect a broad range of factors that vary by school district, to make comparisons about observed differences in the rates of obesity and overweight between school districts requires the use of multivariate statistics. County, regional and statewide estimates will only be provided biennially, District estimates will be updated annually. For more information check out http://www.health.ny.gov/prevention/obesity/, see our Instruction Guide on How to Create Visualizations https://health.data.ny.gov/api/assets/6490BDA9-AE4D-406F-BA5A-703793526B9F or go to the "About" tab.', 'displayType': 'table', 'downloadCount': 5949, 'indexUpdatedAt': 1414628645, 'newBackend': False, 'numberOfComments': 0, 'oid': 8927251, 'publicationAppendEnabled': False, 'publicationDate': 1411499050, 'publicationGroup': 742658, 'publicationStage': 'published', 'rowsUpdatedAt': 1411498834, 'rowsUpdatedBy': 'da2s-ec8k', 'tableId': 1726367, 'totalTimesRated': 0, 'viewCount': 17054, 'viewLastModified': 1411499050, 'viewType': 'tabular', 'columns': [{'id': -1, 'name': 'sid', 'dataTypeName': 'meta_data', 'fieldName': ':sid', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': -1, 'name': 'id', 'dataTypeName': 'meta_data', 'fieldName': ':id', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': -1, 'name': 'position', 'dataTypeName': 'meta_data', 'fieldName': ':position', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': -1, 'name': 'created_at', 'dataTypeName': 'meta_data', 'fieldName': ':created_at', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': -1, 'name': 'created_meta', 'dataTypeName': 'meta_data', 'fieldName': ':created_meta', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': -1, 'name': 'updated_at', 'dataTypeName': 'meta_data', 'fieldName': ':updated_at', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': -1, 'name': 'updated_meta', 'dataTypeName': 'meta_data', 'fieldName': ':updated_meta', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': -1, 'name': 'meta', 'dataTypeName': 'meta_data', 'fieldName': ':meta', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}}, {'id': 168098713, 'name': 'LOCATION CODE', 'dataTypeName': 'text', 'description': '6-digit code identifying the location type. For school districts, this is the 6-digit NYSED district BEDS code. For counties, this is the 6-digit NYSED county code. Regional codes range from 100000 – 700000. Statewide = 000000. ', 'fieldName': 'location_code', 'position': 1, 'renderTypeName': 'text', 'tableColumnId': 8751874, 'width': 130, 'cachedContents': {'non_null': 3270, 'smallest': '000000', 'null': 0, 'largest': '700000', 'top': [{'count': 20, 'item': '660102'}, {'count': 19, 'item': '660202'}, {'count': 18, 'item': '660203'}, {'count': 17, 'item': '660303'}, {'count': 16, 'item': '660402'}, {'count': 15, 'item': '660403'}, {'count': 14, 'item': '660404'}, {'count': 13, 'item': '660405'}, {'count': 12, 'item': '660407'}, {'count': 11, 'item': '660501'}, {'count': 10, 'item': '660801'}, {'count': 9, ' ...

# %%
p = open("estaciones.json","r")
data1 = p.read()
p.close()

print(type(data1))



o = json.loads(data1)
print(type(o))
# Out:
# <class 'str'>
# <class 'dict'>

# %% [markdown]
# para leerlo como diccionario json.loads(data1) .... print(type)(o))

# %%
est = json.loads(data)

# %%
for x in est["estaciones"]:
  if x["nom"] == "MACHU PICCHU":
    print(x["lat"], x["lon"])
# Out:
# -13.16655 -72.54585

# %%
for x in est["estaciones"]:
  if x["nom"] == "CARPISH":
    
    print(x["lat"], x["lon"])
# Out:
# -9.66694 -76.08361

# %%
o = json.loads(data1)
print(type(o))
# Out:
# <class 'dict'>

# %%
p = open("estaciones.json", "w")

# %%
o
# Out:
# {'estaciones': [{'cate': 'CO',
#    'cod': '100090',
#    'cod_old': '000396',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.22499,
#    'lon': -79.15323,
#    'nom': 'MONTE GRANDE'},
#   {'cate': 'PLU',
#    'cod': '106067',
#    'cod_old': '153109',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.27366,
#    'lon': -79.03696,
#    'nom': 'QUEROCOTILLO'},
#   {'cate': 'HLG',
#    'cod': '221110',
#    'cod_old': '220307',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -6.67411,
#    'lon': -78.52437,
#    'nom': 'PUENTE  MAYGASBAMBA'},
#   {'cate': 'PLU',
#    'cod': '100113',
#    'cod_old': '153108',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.68778,
#    'lon': -78.45694,
#    'nom': 'QUEBRADA SHUGAR'},
#   {'cate': 'PLU',
#    'cod': '106077',
#    'cod_old': '153208',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.67091,
#    'lon': -78.73717,
#    'nom': 'CHUGUR'},
#   {'cate': 'CO',
#    'cod': '105062',
#    'cod_old': '000349',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.67175,
#    'lon': -78.89767,
#    'nom': 'LA CASCARILLA'},
#   {'cate': 'CO',
#    'cod': '105065',
#    'cod_old': '000250',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.64389,
#    'lon': -79.09,
#    'nom': 'CHONTALI'},
#   {'cate': 'PLU',
#    'cod': '105110',
#    'cod_old': '152213',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.94222,
#    'lon': -78.85639,
#    'nom': 'PUENTE CHUNCHUCA'},
#   {'cate': 'HLM',
#    'cod': '220405',
#    'cod_old': '220405',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.91694,
#    'lon': -78.95028,
#    'nom': 'CACAO'},
#   {'cate': 'CO',
#    'cod': '105057',
#    'cod_old': '000241',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.91778,
#    'lon': -79.31722,
#    'nom': 'EL LIMON'},
#   {'cate': 'PLU',
#    'cod': '106065',
#    'cod_old': '153107',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.04167,
#    'lon': -79.13389,
#    'nom': 'HACIENDA PUCARA'},
#   {'cate': 'CO',
#    'cod': '105053',
#    'cod_old': '002129',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.65889,
#    'lon': -79.3125,
#    'nom': 'SALLIQUE'},
#   {'cate': 'PLU',
#    'cod': '105111',
#    'cod_old': '152212',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.46639,
#    'lon': -78.98861,
#    'nom': 'COCHALAN'},
#   {'cate': 'HLG',
#    'cod': '220814',
#    'cod_old': '220815',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.46506,
#    'lon': -78.98822,
#    'nom': 'COCHALAN'},
#   {'cate': 'HLG',
#    'cod': '220812',
#    'cod_old': '220813',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.32221,
#    'lon': -79.28779,
#    'nom': 'TABACONAS'},
#   {'cate': 'PLU',
#    'cod': '107055',
#    'cod_old': '153111',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.0802,
#    'lon': -79.04045,
#    'nom': 'LIVES'},
#   {'cate': 'CO',
#    'cod': '106022',
#    'cod_old': '000395',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.575,
#    'lon': -78.86722,
#    'nom': 'CHANCAY BAÑOS'},
#   {'cate': 'HLG',
#    'cod': '106122',
#    'cod_old': '200909',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -6.65579,
#    'lon': -79.07395,
#    'nom': 'CIRATO'},
#   {'cate': 'PE',
#    'cod': '114131',
#    'cod_old': '114131',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.16997,
#    'lon': -71.23187,
#    'nom': 'SALCCA'},
#   {'cate': 'CO',
#    'cod': '114032',
#    'cod_old': '000757',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.81694,
#    'lon': -71.41694,
#    'nom': 'YAURI'},
#   {'cate': 'CO',
#    'cod': '113139',
#    'cod_old': '155518',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.10855,
#    'lon': -71.72,
#    'nom': 'CHACLLABAMBA'},
#   {'cate': 'CO',
#    'cod': '100030',
#    'cod_old': '006671',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.02389,
#    'lon': -71.46778,
#    'nom': 'CHONTACHACA'},
#   {'cate': 'CO',
#    'cod': '112142',
#    'cod_old': '156126',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.53944,
#    'lon': -75.23667,
#    'nom': 'HUANCALPI'},
#   {'cate': 'CO',
#    'cod': '113067',
#    'cod_old': '151503',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.2206,
#    'lon': -75.53348,
#    'nom': 'HUACHOS'},
#   {'cate': 'CO',
#    'cod': '113082',
#    'cod_old': '156114',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.21198,
#    'lon': -75.62758,
#    'nom': 'SAN JUAN DE CASTROVIRREYNA'},
#   {'cate': 'CO',
#    'cod': '113091',
#    'cod_old': '156130',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.1588,
#    'lon': -75.07145,
#    'nom': 'CHOCLOCOCHA'},
#   {'cate': 'CO',
#    'cod': '112066',
#    'cod_old': '000658',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.46667,
#    'lon': -74.56667,
#    'nom': 'PAUCARBAMBA'},
#   {'cate': 'PLU',
#    'cod': '114065',
#    'cod_old': '157101',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.04061,
#    'lon': -75.18698,
#    'nom': 'CORDOVA'},
#   {'cate': 'CO',
#    'cod': '113016',
#    'cod_old': '000647',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.25932,
#    'lon': -75.08596,
#    'nom': 'TUNEL CERO'},
#   {'cate': 'CO',
#    'cod': '113086',
#    'cod_old': '156121',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.50399,
#    'lon': -75.29625,
#    'nom': 'CUSICANCHA'},
#   {'cate': 'PLU',
#    'cod': '100025',
#    'cod_old': '000009',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.79194,
#    'lon': -75.39056,
#    'nom': 'CHALLACA PLU'},
#   {'cate': 'CO',
#    'cod': '113128',
#    'cod_old': '006640',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.79047,
#    'lon': -75.38212,
#    'nom': 'CHALLACA CO'},
#   {'cate': 'CO',
#    'cod': '113088',
#    'cod_old': '156123',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.83308,
#    'lon': -75.25083,
#    'nom': 'SANTIAGO DE CHOCORVOS'},
#   {'cate': 'CO',
#    'cod': '113087',
#    'cod_old': '156122',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.69163,
#    'lon': -75.27418,
#    'nom': 'TAMBO'},
#   {'cate': 'HLM',
#    'cod': '230003',
#    'cod_old': '230003',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -9.515,
#    'lon': -75.9425,
#    'nom': 'CHINCHAVITO'},
#   {'cate': 'CO',
#    'cod': '109020',
#    'cod_old': '000454',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -9.66694,
#    'lon': -76.08361,
#    'nom': 'CARPISH'},
#   {'cate': 'HLM',
#    'cod': '230002',
#    'cod_old': '230002',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -9.84694,
#    'lon': -76.15111,
#    'nom': 'TARUCA'},
#   {'cate': 'HLM',
#    'cod': '230004',
#    'cod_old': '230004',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -9.32,
#    'lon': -76.02778,
#    'nom': 'PUENTE BELLA'},
#   {'cate': 'HLM',
#    'cod': '230001',
#    'cod_old': '230001',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -9.34694,
#    'lon': -75.9825,
#    'nom': 'PUENTE PEREZ'},
#   {'cate': 'PLU',
#    'cod': '113244',
#    'cod_old': '113244',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.92472,
#    'lon': -75.67861,
#    'nom': 'LOS MOLINOS'},
#   {'cate': 'HLG',
#    'cod': '203501',
#    'cod_old': '203501',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -13.43942,
#    'lon': -75.97514,
#    'nom': 'CONTA'},
#   {'cate': 'PLU',
#    'cod': '114106',
#    'cod_old': '156225',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.63333,
#    'lon': -74.95,
#    'nom': 'HUALLPOCA'},
#   {'cate': 'CO',
#    'cod': '115092',
#    'cod_old': '157317',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.60999,
#    'lon': -71.80654,
#    'nom': 'MADRIGAL'},
#   {'cate': 'HLG',
#    'cod': '204702',
#    'cod_old': '204702',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -15.81667,
#    'lon': -71.11667,
#    'nom': 'SUMBAY'},
#   {'cate': 'CO',
#    'cod': '115126',
#    'cod_old': '158208',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.97861,
#    'lon': -71.21333,
#    'nom': 'PILLONES'},
#   {'cate': 'HLG',
#    'cod': '204604',
#    'cod_old': '204604',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -15.48929,
#    'lon': -71.45705,
#    'nom': 'PUENTE COLGANTE-SIBAYO'},
#   {'cate': 'CO',
#    'cod': '115101',
#    'cod_old': '157329',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.35,
#    'lon': -71.31667,
#    'nom': 'PORPERA'},
#   {'cate': 'CO',
#    'cod': '115098',
#    'cod_old': '157325',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.35,
#    'lon': -71.45,
#    'nom': 'TISCO'},
#   {'cate': 'CO',
#    'cod': '115078',
#    'cod_old': '157300',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.54811,
#    'lon': -72.91831,
#    'nom': 'CHICHAS'},
#   {'cate': 'HLM',
#    'cod': '204501',
#    'cod_old': '204501',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -15.85,
#    'lon': -72.83333,
#    'nom': 'SALAMANCA'},
#   {'cate': 'CO',
#    'cod': '115128',
#    'cod_old': '000864',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.78306,
#    'lon': -72.88278,
#    'nom': 'YANAQUIHUA'},
#   {'cate': 'CO',
#    'cod': '117006',
#    'cod_old': '000838',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.99917,
#    'lon': -71.58861,
#    'nom': 'LA HACIENDITA'},
#   {'cate': 'HLM',
#    'cod': '204506',
#    'cod_old': '204508',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -15.21251,
#    'lon': -72.92919,
#    'nom': 'CUYAU'},
#   {'cate': 'CO',
#    'cod': '115084',
#    'cod_old': '157309',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.13583,
#    'lon': -72.75278,
#    'nom': 'PULLHUAY (AYAHUASI)'},
#   {'cate': 'CO',
#    'cod': '115082',
#    'cod_old': '157307',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.0605,
#    'lon': -72.69228,
#    'nom': 'PUICA'},
#   {'cate': 'CO',
#    'cod': '100055',
#    'cod_old': '156218',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.91694,
#    'lon': -74.33361,
#    'nom': 'HUANCASANCOS'},
#   {'cate': 'CO',
#    'cod': '112068',
#    'cod_old': '000660',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.94597,
#    'lon': -74.24567,
#    'nom': 'HUANTA'},
#   {'cate': 'HLG',
#    'cod': '230705',
#    'cod_old': '230705',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -14.26667,
#    'lon': -73.95,
#    'nom': 'HUASAPAMPA'},
#   {'cate': 'PLU',
#    'cod': '114067',
#    'cod_old': '157200',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.24639,
#    'lon': -74.92556,
#    'nom': 'LLAUTA'},
#   {'cate': 'PLU',
#    'cod': '114072',
#    'cod_old': '157206',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.62,
#    'lon': -74.23223,
#    'nom': 'LUCANAS'},
#   {'cate': 'PLU',
#    'cod': '115076',
#    'cod_old': '157223',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.18468,
#    'lon': -73.34786,
#    'nom': 'LAMPA'},
#   {'cate': 'CO',
#    'cod': '113101',
#    'cod_old': '156212',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.88257,
#    'lon': -73.72658,
#    'nom': 'CHILCAYOC'},
#   {'cate': 'PE',
#    'cod': '107033',
#    'cod_old': '000316',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.19345,
#    'lon': -78.51012,
#    'nom': 'AYLAMBO'},
#   {'cate': 'PE',
#    'cod': '107035',
#    'cod_old': '000318',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.19119,
#    'lon': -78.45947,
#    'nom': 'LA VICTORIA'},
#   {'cate': 'PLU',
#    'cod': '106084',
#    'cod_old': '153235',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.55972,
#    'lon': -78.74833,
#    'nom': 'CHOTANO LAJAS'},
#   {'cate': 'HLM',
#    'cod': '201301',
#    'cod_old': '201301',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -7.38332,
#    'lon': -78.73377,
#    'nom': 'CASCABAMBA'},
#   {'cate': 'PLU',
#    'cod': '110051',
#    'cod_old': '155105',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.40457,
#    'lon': -77.40025,
#    'nom': 'OCROS'},
#   {'cate': 'HLG',
#    'cod': '202404',
#    'cod_old': '202404',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -10.606,
#    'lon': -77.34389,
#    'nom': 'CAHUA'},
#   {'cate': 'PLU',
#    'cod': '109095',
#    'cod_old': '109095',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -9.85242,
#    'lon': -77.40607,
#    'nom': 'NUEVO PACHACOTO'},
#   {'cate': 'CO',
#    'cod': '105104',
#    'cod_old': '000229',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.16144,
#    'lon': -78.28806,
#    'nom': 'CHIRIACO'},
#   {'cate': 'CO',
#    'cod': '104060',
#    'cod_old': '000256',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.83039,
#    'lon': -77.93928,
#    'nom': 'SANTA MARIA DE NIEVA'},
#   {'cate': 'PLU',
#    'cod': '105040',
#    'cod_old': '152204',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.7562,
#    'lon': -78.52286,
#    'nom': 'EL PINTOR'},
#   {'cate': 'PLU',
#    'cod': '105046',
#    'cod_old': '152210',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.89106,
#    'lon': -78.18886,
#    'nom': 'MAGUNCHAL'},
#   {'cate': 'HLG',
#    'cod': '221506',
#    'cod_old': '221506',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.89006,
#    'lon': -78.18765,
#    'nom': 'MAGUNCHAL'},
#   {'cate': 'CO',
#    'cod': '106121',
#    'cod_old': '003332',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.00039,
#    'lon': -78.47097,
#    'nom': 'EL PALTO'},
#   {'cate': 'HLM',
#    'cod': '211404',
#    'cod_old': '201720',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -9.60776,
#    'lon': -77.50963,
#    'nom': 'SAN PEDRO'},
#   {'cate': 'MAP',
#    'cod': '109009',
#    'cod_old': '000426',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -9.51653,
#    'lon': -77.52486,
#    'nom': 'SANTIAGO ANTUNEZ DE MAYOLO'},
#   {'cate': 'PLU',
#    'cod': '109045',
#    'cod_old': '154107',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -9.53519,
#    'lon': -77.77536,
#    'nom': 'CHACCHAN'},
#   {'cate': 'PLU',
#    'cod': '109048',
#    'cod_old': '154110',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -9.58528,
#    'lon': -77.70719,
#    'nom': 'PIRA'},
#   {'cate': 'PLU',
#    'cod': '110040',
#    'cod_old': '150903',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.15775,
#    'lon': -77.34889,
#    'nom': 'MAYORARCA'},
#   {'cate': 'CO',
#    'cod': '109014',
#    'cod_old': '000435',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -9.43371,
#    'lon': -78.20825,
#    'nom': 'BUENA VISTA'},
#   {'cate': 'PLU',
#    'cod': '113136',
#    'cod_old': '156224',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.56,
#    'lon': -72.57389,
#    'nom': 'CUNYAC'},
#   {'cate': 'HLG',
#    'cod': '204710',
#    'cod_old': '204711',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -16.31086,
#    'lon': -71.49511,
#    'nom': 'CHARCANI'},
#   {'cate': 'CO',
#    'cod': '116046',
#    'cod_old': '158209',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.31778,
#    'lon': -71.14806,
#    'nom': 'LAS SALINAS'},
#   {'cate': 'CO',
#    'cod': '116022',
#    'cod_old': '000849',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.15482,
#    'lon': -71.1891,
#    'nom': 'EL FRAYLE'},
#   {'cate': 'CO',
#    'cod': '116073',
#    'cod_old': '116073',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.05542,
#    'lon': -71.41481,
#    'nom': 'PATAHUASI-AREQUIPA'},
#   {'cate': 'CO',
#    'cod': '116043',
#    'cod_old': '158204',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.06306,
#    'lon': -71.58889,
#    'nom': 'PAMPA DE ARRIEROS'},
#   {'cate': 'CO',
#    'cod': '115088',
#    'cod_old': '157313',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.67917,
#    'lon': -72.27028,
#    'nom': 'AYO'},
#   {'cate': 'CO',
#    'cod': '115087',
#    'cod_old': '157312',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.50242,
#    'lon': -72.26852,
#    'nom': 'CHACHAS'},
#   {'cate': 'PLU',
#    'cod': '110041',
#    'cod_old': '151208',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.62136,
#    'lon': -77.04027,
#    'nom': 'GORGOR'},
#   {'cate': 'PLU',
#    'cod': '111057',
#    'cod_old': '151204',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.61667,
#    'lon': -76.7,
#    'nom': 'ARAHUAY'},
#   {'cate': 'PLU',
#    'cod': '111085',
#    'cod_old': '155209',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.5,
#    'lon': -76.75,
#    'nom': 'HUAMANTANGA'},
#   {'cate': 'PLU',
#    'cod': '111089',
#    'cod_old': '155218',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.40743,
#    'lon': -76.5758,
#    'nom': 'HUAROS'},
#   {'cate': 'HLM',
#    'cod': '202801',
#    'cod_old': '202801',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -11.39315,
#    'lon': -76.50244,
#    'nom': 'PARIACANCHA'},
#   {'cate': 'PLU',
#    'cod': '111067',
#    'cod_old': '155112',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.39357,
#    'lon': -76.50271,
#    'nom': 'PARIACANCHA'},
#   {'cate': 'PLU',
#    'cod': '111088',
#    'cod_old': '155217',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.55327,
#    'lon': -76.62844,
#    'nom': 'LACHAQUI'},
#   {'cate': 'PLU',
#    'cod': '111159',
#    'cod_old': '156133',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.45264,
#    'lon': -76.62206,
#    'nom': 'OBRAJILLO'},
#   {'cate': 'CO',
#    'cod': '112054',
#    'cod_old': '000631',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.52169,
#    'lon': -76.49314,
#    'nom': 'LA CAPILLA  2'},
#   {'cate': 'PLU',
#    'cod': '111087',
#    'cod_old': '155214',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.2328,
#    'lon': -76.65513,
#    'nom': 'PIRCA'},
#   {'cate': 'PLU',
#    'cod': '111083',
#    'cod_old': '155205',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.34874,
#    'lon': -76.80804,
#    'nom': 'PALLAC'},
#   {'cate': 'HLM',
#    'cod': '240102',
#    'cod_old': '240101',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.72722,
#    'lon': -73.23694,
#    'nom': 'ENAPU PERU'},
#   {'cate': 'HLM',
#    'cod': '240302',
#    'cod_old': '240302',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.82743,
#    'lon': -73.37741,
#    'nom': 'PUERTO ALMENDRA'},
#   {'cate': 'HLM',
#    'cod': '240106',
#    'cod_old': '240105',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.75361,
#    'lon': -73.28056,
#    'nom': 'SEDA LORETO'},
#   {'cate': 'CP',
#    'cod': '103023',
#    'cod_old': '000153',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.89967,
#    'lon': -73.33833,
#    'nom': 'MORALILLO'},
#   {'cate': 'HLM',
#    'cod': '240401',
#    'cod_old': '240111',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.17378,
#    'lon': -72.89205,
#    'nom': 'ANGAMOS'},
#   {'cate': 'CO',
#    'cod': '105078',
#    'cod_old': '000269',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.14913,
#    'lon': -72.89205,
#    'nom': 'ANGAMOS'},
#   {'cate': 'HLM',
#    'cod': '240402',
#    'cod_old': '240402',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -2.44506,
#    'lon': -72.66739,
#    'nom': 'EL ESTRECHO'},
#   {'cate': 'CO',
#    'cod': '102006',
#    'cod_old': '000110',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -2.44767,
#    'lon': -72.66747,
#    'nom': 'EL ESTRECHO'},
#   {'cate': 'PLU',
#    'cod': '111081',
#    'cod_old': '155202',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.19827,
#    'lon': -76.63487,
#    'nom': 'SANTA CRUZ'},
#   {'cate': 'PE',
#    'cod': '112124',
#    'cod_old': '156100',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.08333,
#    'lon': -76.5,
#    'nom': 'ANTIOQUIA'},
#   {'cate': 'PLU',
#    'cod': '111091',
#    'cod_old': '155223',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.65503,
#    'lon': -76.51514,
#    'nom': 'CARAMPOMA'},
#   {'cate': 'PLU',
#    'cod': '111062',
#    'cod_old': '151213',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.66095,
#    'lon': -76.5023,
#    'nom': 'SHEQUE'},
#   {'cate': 'HLM',
#    'cod': '202902',
#    'cod_old': '202902',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -11.57046,
#    'lon': -76.35017,
#    'nom': 'MILLOC'},
#   {'cate': 'PLU',
#    'cod': '111144',
#    'cod_old': '155514',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.57131,
#    'lon': -76.34995,
#    'nom': 'MILLOC'},
#   {'cate': 'PLU',
#    'cod': '111114',
#    'cod_old': '155446',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.63804,
#    'lon': -76.23332,
#    'nom': 'CASAPALCA'},
#   {'cate': 'PLU',
#    'cod': '111061',
#    'cod_old': '151210',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.73447,
#    'lon': -76.25967,
#    'nom': 'RIO BLANCO'},
#   {'cate': 'PLU',
#    'cod': '111066',
#    'cod_old': '155111',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.61667,
#    'lon': -76.48334,
#    'nom': 'TINGO'},
#   {'cate': 'PLU',
#    'cod': '112082',
#    'cod_old': '151214',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.12645,
#    'lon': -76.42108,
#    'nom': 'LANGA'},
#   {'cate': 'PLU',
#    'cod': '111077',
#    'cod_old': '155122',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.73815,
#    'lon': -76.61103,
#    'nom': 'AUTISHA'},
#   {'cate': 'HLM',
#    'cod': '202903',
#    'cod_old': '202903',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -11.73523,
#    'lon': -76.60659,
#    'nom': 'AUTISHA'},
#   {'cate': 'PLU',
#    'cod': '111093',
#    'cod_old': '155225',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.80053,
#    'lon': -76.25811,
#    'nom': 'SAN JOSE DE PARAC'},
#   {'cate': 'PLU',
#    'cod': '111291',
#    'cod_old': '111291',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.84685,
#    'lon': -76.56358,
#    'nom': 'SAN MATEO DE OTAO'},
#   {'cate': 'PLU',
#    'cod': '112080',
#    'cod_old': '151207',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.18618,
#    'lon': -76.24066,
#    'nom': 'HUANCATA'},
#   {'cate': 'PLU',
#    'cod': '111092',
#    'cod_old': '155224',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.98311,
#    'lon': -76.52415,
#    'nom': 'SANTIAGO DE TUNA'},
#   {'cate': 'PLU',
#    'cod': '110042',
#    'cod_old': '151211',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.75,
#    'lon': -77.28333,
#    'nom': 'AMBAR'},
#   {'cate': 'CO',
#    'cod': '110053',
#    'cod_old': '155107',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.86578,
#    'lon': -76.97,
#    'nom': 'PAMPA LIBRE'},
#   {'cate': 'PLU',
#    'cod': '111084',
#    'cod_old': '155207',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.06525,
#    'lon': -76.9141,
#    'nom': 'PACHAMACHAY'},
#   {'cate': 'PLU',
#    'cod': '110056',
#    'cod_old': '155200',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.95,
#    'lon': -76.93333,
#    'nom': 'PACCHO'},
#   {'cate': 'PLU',
#    'cod': '110063',
#    'cod_old': '155212',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.96665,
#    'lon': -76.71983,
#    'nom': 'PARQUIN'},
#   {'cate': 'HLG',
#    'cod': '202601',
#    'cod_old': '202601',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -10.51667,
#    'lon': -76.78333,
#    'nom': 'LAGUNA SURASACA'},
#   {'cate': 'PLU',
#    'cod': '110059',
#    'cod_old': '155206',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.52383,
#    'lon': -76.78667,
#    'nom': 'LAGUNA SURASACA'},
#   {'cate': 'PLU',
#    'cod': '110092',
#    'cod_old': '155291',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.78333,
#    'lon': -76.66667,
#    'nom': 'LAGUNA COCHAQUILLO'},
#   {'cate': 'CO',
#    'cod': '110020',
#    'cod_old': '000541',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.66769,
#    'lon': -76.7687,
#    'nom': 'OYON'},
#   {'cate': 'PLU',
#    'cod': '110057',
#    'cod_old': '155201',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.78333,
#    'lon': -76.9,
#    'nom': 'ANDAJES'},
#   {'cate': 'PLU',
#    'cod': '112096',
#    'cod_old': '155450',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.31478,
#    'lon': -75.71209,
#    'nom': 'YAURICOCHA'},
#   {'cate': 'PLU',
#    'cod': '112128',
#    'cod_old': '156104',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.38208,
#    'lon': -76.13672,
#    'nom': 'AYAVIRI'},
#   {'cate': 'PE',
#    'cod': '112133',
#    'cod_old': '156109',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.3444,
#    'lon': -75.87215,
#    'nom': 'CARANIA'},
#   {'cate': 'PE',
#    'cod': '112135',
#    'cod_old': '156111',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.11457,
#    'lon': -75.82617,
#    'nom': 'VILCA'},
#   {'cate': 'PLU',
#    'cod': '112127',
#    'cod_old': '156103',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.29359,
#    'lon': -76.13902,
#    'nom': 'HUAÑEC'},
#   {'cate': 'PLU',
#    'cod': '112081',
#    'cod_old': '151212',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.4548,
#    'lon': -76.22559,
#    'nom': 'SAN PEDRO DE PILAS'},
#   {'cate': 'PE',
#    'cod': '112130',
#    'cod_old': '156106',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.11667,
#    'lon': -76.01667,
#    'nom': 'TANTA'},
#   {'cate': 'CO',
#    'cod': '103057',
#    'cod_old': '000154',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.76397,
#    'lon': -73.25492,
#    'nom': 'AMAZONAS'},
#   {'cate': 'CP',
#    'cod': '103052',
#    'cod_old': '000176',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.78667,
#    'lon': -73.29333,
#    'nom': 'SAN ROQUE'},
#   {'cate': 'HLM',
#    'cod': '240001',
#    'cod_old': '240110',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.83361,
#    'lon': -73.66694,
#    'nom': 'SANTA MARIA NANAY'},
#   {'cate': 'PE',
#    'cod': '103009',
#    'cod_old': '150201',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.51972,
#    'lon': -72.8405,
#    'nom': 'MANITI'},
#   {'cate': 'PLU',
#    'cod': '103011',
#    'cod_old': '150204',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.52311,
#    'lon': -73.08333,
#    'nom': 'TIMICURILLO'},
#   {'cate': 'HLM',
#    'cod': '240202',
#    'cod_old': '240202',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.51694,
#    'lon': -73.08361,
#    'nom': 'TIMICURILLO'},
#   {'cate': 'HLM',
#    'cod': '240111',
#    'cod_old': '260102',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.48206,
#    'lon': -73.0735,
#    'nom': 'BELLAVISTA'},
#   {'cate': 'PLU',
#    'cod': '103012',
#    'cod_old': '150205',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.48261,
#    'lon': -73.63333,
#    'nom': 'BELLAVISTA'},
#   {'cate': 'PLU',
#    'cod': '103014',
#    'cod_old': '150207',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.4625,
#    'lon': -73.24056,
#    'nom': 'LA LIBERTAD'},
#   {'cate': 'HLM',
#    'cod': '240112',
#    'cod_old': '260201',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.45694,
#    'lon': -73.24222,
#    'nom': 'LA LIBERTAD'},
#   {'cate': 'PLU',
#    'cod': '103013',
#    'cod_old': '150206',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.50028,
#    'lon': -73.13361,
#    'nom': 'SANTA CRUZ'},
#   {'cate': 'HLM',
#    'cod': '240109',
#    'cod_old': '240109',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -3.50028,
#    'lon': -73.13361,
#    'nom': 'SANTA CRUZ'},
#   {'cate': 'PLU',
#    'cod': '103030',
#    'cod_old': '152409',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.8894,
#    'lon': -73.69617,
#    'nom': 'SANTA MARIA DE NANAY'},
#   {'cate': 'HLM',
#    'cod': '240110',
#    'cod_old': '260101',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -2.48747,
#    'lon': -73.67922,
#    'nom': 'SANTA CLOTILDE'},
#   {'cate': 'HLM',
#    'cod': '230602',
#    'cod_old': '230602',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.898,
#    'lon': -76.101,
#    'nom': 'YURIMAGUAS ENP'},
#   {'cate': 'CO',
#    'cod': '100132',
#    'cod_old': '153315',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.07139,
#    'lon': -76.25861,
#    'nom': 'SHANUSI'},
#   {'cate': 'PLU',
#    'cod': '100080',
#    'cod_old': '152304',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.22173,
#    'lon': -75.66546,
#    'nom': 'LAGUNAS'},
#   {'cate': 'PLU',
#    'cod': '104061',
#    'cod_old': '000270',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.45028,
#    'lon': -77.45028,
#    'nom': 'BORJA'},
#   {'cate': 'HLM',
#    'cod': '220107',
#    'cod_old': '220107',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -4.47,
#    'lon': -77.548,
#    'nom': 'BORJA'},
#   {'cate': 'HLM',
#    'cod': '221402',
#    'cod_old': '221401',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -4.50736,
#    'lon': -73.5733,
#    'nom': 'NAUTA'},
#   {'cate': 'PE',
#    'cod': '104098',
#    'cod_old': '150212',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.51083,
#    'lon': -73.90972,
#    'nom': 'SAN REGIS'},
#   {'cate': 'HLM',
#    'cod': '220105',
#    'cod_old': '220105',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -4.51439,
#    'lon': -73.9054,
#    'nom': 'SAN REGIS'},
#   {'cate': 'PE',
#    'cod': '104067',
#    'cod_old': '152406',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.75963,
#    'lon': -73.60377,
#    'nom': 'BAGAZAN'},
#   {'cate': 'PE',
#    'cod': '104065',
#    'cod_old': '152401',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.61388,
#    'lon': -74.3738,
#    'nom': 'SANTA RITA DE CASTILLA'},
#   {'cate': 'PLU',
#    'cod': '104010',
#    'cod_old': '150209',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.22636,
#    'lon': -69.95629,
#    'nom': 'SANTA ROSA'},
#   {'cate': 'HLM',
#    'cod': '240108',
#    'cod_old': '240108',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -4.25785,
#    'lon': -69.95334,
#    'nom': 'SANTA ROSA'},
#   {'cate': 'CO',
#    'cod': '105095',
#    'cod_old': '000280',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.04264,
#    'lon': -73.83556,
#    'nom': 'REQUENA'},
#   {'cate': 'HLM',
#    'cod': '250101',
#    'cod_old': '250101',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.04169,
#    'lon': -73.83829,
#    'nom': 'REQUENA'},
#   {'cate': 'HLM',
#    'cod': '251100',
#    'cod_old': '231302',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.40779,
#    'lon': -74.157,
#    'nom': 'FLOR DE PUNGA'},
#   {'cate': 'PLU',
#    'cod': '105091',
#    'cod_old': '152403',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.79442,
#    'lon': -74.28375,
#    'nom': 'TAMANCO'},
#   {'cate': 'CO',
#    'cod': '105092',
#    'cod_old': '152405',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.40544,
#    'lon': -74.15839,
#    'nom': 'FLOR DE PUNGA'},
#   {'cate': 'PE',
#    'cod': '105090',
#    'cod_old': '152402',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.26568,
#    'lon': -74.35638,
#    'nom': 'BRETAÑA'},
#   {'cate': 'HLM',
#    'cod': '251104',
#    'cod_old': '231303',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -4.90442,
#    'lon': -73.64972,
#    'nom': 'GENARO HERRERA'},
#   {'cate': 'HLM',
#    'cod': '251102',
#    'cod_old': '231301',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -7.35208,
#    'lon': -75.00056,
#    'nom': 'CONTAMANA'},
#   {'cate': 'CO',
#    'cod': '100034',
#    'cod_old': '000387',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.35222,
#    'lon': -75.00583,
#    'nom': 'CONTAMANA'},
#   {'cate': 'CO',
#    'cod': '116049',
#    'cod_old': '158301',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.77944,
#    'lon': -70.89778,
#    'nom': 'QUINISTAQUILLAS'},
#   {'cate': 'PLU',
#    'cod': '117031',
#    'cod_old': '158314',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.13361,
#    'lon': -70.83361,
#    'nom': 'TUMILACA'},
#   {'cate': 'CO',
#    'cod': '100150',
#    'cod_old': '000852',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.09661,
#    'lon': -70.86753,
#    'nom': 'YACANGO'},
#   {'cate': 'HLG',
#    'cod': '214700',
#    'cod_old': '204812',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -17.00694,
#    'lon': -70.85336,
#    'nom': 'OTORA'},
#   {'cate': 'HLG',
#    'cod': '204804',
#    'cod_old': '204804',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -17.16694,
#    'lon': -70.75028,
#    'nom': 'TUMILACA'},
#   {'cate': 'PLU',
#    'cod': '117024',
#    'cod_old': '158302',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.00722,
#    'lon': -70.85361,
#    'nom': 'OTORA'},
#   {'cate': 'CO',
#    'cod': '116023',
#    'cod_old': '000850',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.6775,
#    'lon': -70.9825,
#    'nom': 'OMATE'},
#   {'cate': 'MAP',
#    'cod': '105100',
#    'cod_old': '000207',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.17528,
#    'lon': -80.61654,
#    'nom': 'MIRAFLORES'},
#   {'cate': 'PLU',
#    'cod': '100105',
#    'cod_old': '152132',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.83964,
#    'lon': -79.50572,
#    'nom': 'PORCULLA'},
#   {'cate': 'PLU',
#    'cod': '105024',
#    'cod_old': '152128',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.36681,
#    'lon': -79.36056,
#    'nom': 'HACIENDA SHUMAYA'},
#   {'cate': 'PLU',
#    'cod': '105023',
#    'cod_old': '152127',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.47718,
#    'lon': -79.34742,
#    'nom': 'TULUCE'},
#   {'cate': 'HLG',
#    'cod': '220509',
#    'cod_old': '220510',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -5.33922,
#    'lon': -79.41575,
#    'nom': 'SONDORILLO'},
#   {'cate': 'PLU',
#    'cod': '105015',
#    'cod_old': '152111',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.3209,
#    'lon': -79.7857,
#    'nom': 'HACIENDA BIGOTE'},
#   {'cate': 'PLU',
#    'cod': '104044',
#    'cod_old': '152153',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.4792,
#    'lon': -80.39783,
#    'nom': 'ALAMOR'},
#   {'cate': 'HLM',
#    'cod': '200322',
#    'cod_old': '200324',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -4.4792,
#    'lon': -80.3978,
#    'nom': 'ALAMOR'},
#   {'cate': 'PLU',
#    'cod': '104014',
#    'cod_old': '152101',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -4.51556,
#    'lon': -80.73945,
#    'nom': 'PANANGA'},
#   {'cate': 'CO',
#    'cod': '114040',
#    'cod_old': '000778',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.69011,
#    'lon': -70.02353,
#    'nom': 'PROGRESO'},
#   {'cate': 'CO',
#    'cod': '113044',
#    'cod_old': '000695',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.80389,
#    'lon': -70.49714,
#    'nom': 'OLLACHEA'},
#   {'cate': 'CO',
#    'cod': '113119',
#    'cod_old': '156401',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.44081,
#    'lon': -70.40492,
#    'nom': 'SAN GABAN'},
#   {'cate': 'CO',
#    'cod': '116060',
#    'cod_old': '000883',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.56335,
#    'lon': -69.03883,
#    'nom': 'DESAGUADERO'},
#   {'cate': 'PLU',
#    'cod': '116075',
#    'cod_old': '116075',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.57225,
#    'lon': -69.31697,
#    'nom': 'CALLACAME'},
#   {'cate': 'CO',
#    'cod': '117041',
#    'cod_old': '158326',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.18772,
#    'lon': -69.7355,
#    'nom': 'CAPAZO'},
#   {'cate': 'CO',
#    'cod': '115053',
#    'cod_old': '000827',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.01667,
#    'lon': -69.35556,
#    'nom': 'COJATA'},
#   {'cate': 'PLU',
#    'cod': '270200',
#    'cod_old': '157733',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.25544,
#    'lon': -69.87381,
#    'nom': 'RAMIS'},
#   {'cate': 'CO',
#    'cod': '115047',
#    'cod_old': '000816',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.31167,
#    'lon': -69.97247,
#    'nom': 'TARACO'},
#   {'cate': 'CP',
#    'cod': '114035',
#    'cod_old': '000764',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.78478,
#    'lon': -70.71569,
#    'nom': 'CHUQUIBAMBILLA'},
#   {'cate': 'CO',
#    'cod': '100065',
#    'cod_old': '000817',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.56228,
#    'lon': -69.48883,
#    'nom': 'ISLA SOTO'},
#   {'cate': 'CO',
#    'cod': '115138',
#    'cod_old': '007454',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -15.47444,
#    'lon': -70.16944,
#    'nom': 'JULIACA'},
#   {'cate': 'HLM',
#    'cod': '210406',
#    'cod_old': '210406',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -15.47211,
#    'lon': -70.22436,
#    'nom': 'PUENTE ISLA CABANILLAS'},
#   {'cate': 'HLM',
#    'cod': '210405',
#    'cod_old': '210405',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -15.44386,
#    'lon': -70.20903,
#    'nom': 'LAMPA'},
#   {'cate': 'CO',
#    'cod': '114096',
#    'cod_old': '157418',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.48892,
#    'lon': -69.549,
#    'nom': 'CUYO CUYO'},
#   {'cate': 'CO',
#    'cod': '114049',
#    'cod_old': '000825',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -14.15375,
#    'lon': -69.70561,
#    'nom': 'LIMBANI'},
#   {'cate': 'HLG',
#    'cod': '260501',
#    'cod_old': '260501',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -14.15375,
#    'lon': -69.70561,
#    'nom': 'LIMBANI'},
#   {'cate': 'CO',
#    'cod': '116030',
#    'cod_old': '000882',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.30783,
#    'lon': -69.07472,
#    'nom': 'TAHUACO - YUNGUYO'},
#   {'cate': 'CO',
#    'cod': '116009',
#    'cod_old': '000822',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.33022,
#    'lon': -68.85094,
#    'nom': 'ISLA SUANA'},
#   {'cate': 'CO',
#    'cod': '107069',
#    'cod_old': '153225',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.40778,
#    'lon': -76.40611,
#    'nom': 'DOS DE MAYO (J. OLAYA)'},
#   {'cate': 'PLU',
#    'cod': '107095',
#    'cod_old': '153345',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.26292,
#    'lon': -76.48611,
#    'nom': 'CUZCO-BIAVO'},
#   {'cate': 'HLG',
#    'cod': '221804',
#    'cod_old': '221804',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -7.26667,
#    'lon': -76.5,
#    'nom': 'BIAVO'},
#   {'cate': 'CO',
#    'cod': '107013',
#    'cod_old': '000384',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.17222,
#    'lon': -76.48722,
#    'nom': 'LA UNION'},
#   {'cate': 'CO',
#    'cod': '107089',
#    'cod_old': '153312',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.12611,
#    'lon': -76.48278,
#    'nom': 'NUEVO LIMA'},
#   {'cate': 'CO',
#    'cod': '110127',
#    'cod_old': '110127',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.28333,
#    'lon': -76.85,
#    'nom': 'PACAYZAPA'},
#   {'cate': 'PLU',
#    'cod': '106115',
#    'cod_old': '153328',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.41312,
#    'lon': -76.60028,
#    'nom': 'SHANAO'},
#   {'cate': 'HLG',
#    'cod': '221802',
#    'cod_old': '221802',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -6.41291,
#    'lon': -76.60001,
#    'nom': 'SHANAO'},
#   {'cate': 'PLU',
#    'cod': '106094',
#    'cod_old': '153311',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.50028,
#    'lon': -76.50028,
#    'nom': 'CUÑUMBUQUE'},
#   {'cate': 'PLU',
#    'cod': '107101',
#    'cod_old': '153350',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.23333,
#    'lon': -76.75,
#    'nom': 'HUAYABAMBA'},
#   {'cate': 'CO',
#    'cod': '100019',
#    'cod_old': '003304',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.44222,
#    'lon': -76.67,
#    'nom': 'CAMPANILLA'},
#   {'cate': 'HLM',
#    'cod': '221821',
#    'cod_old': '221902',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -7.43333,
#    'lon': -76.68333,
#    'nom': 'CAMPANILLA'},
#   {'cate': 'PLU',
#    'cod': '106095',
#    'cod_old': '153313',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.93361,
#    'lon': -76.33361,
#    'nom': 'PICOTA'},
#   {'cate': 'CO',
#    'cod': '105103',
#    'cod_old': '000219',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.82611,
#    'lon': -77.38722,
#    'nom': 'NARANJILLO'},
#   {'cate': 'HLM',
#    'cod': '221806',
#    'cod_old': '221807',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -6.71667,
#    'lon': -76.25,
#    'nom': 'LAGUNA SAUCE'},
#   {'cate': 'CO',
#    'cod': '106018',
#    'cod_old': '000386',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.35153,
#    'lon': -75.77361,
#    'nom': 'NAVARRO'},
#   {'cate': 'CO',
#    'cod': '106112',
#    'cod_old': '153322',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.21556,
#    'lon': -75.79,
#    'nom': 'PELEJO'},
#   {'cate': 'PLU',
#    'cod': '106110',
#    'cod_old': '153320',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.45278,
#    'lon': -75.84556,
#    'nom': 'PUCALLPA - HUIMBAYOC'},
#   {'cate': 'HLG',
#    'cod': '221801',
#    'cod_old': '221801',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -6.46694,
#    'lon': -76.38361,
#    'nom': 'CUMBAZA'},
#   {'cate': 'CO',
#    'cod': '106096',
#    'cod_old': '153314',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.41694,
#    'lon': -76.41694,
#    'nom': 'SAN ANTONIO'},
#   {'cate': 'HLM',
#    'cod': '215000',
#    'cod_old': '205206',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -17.91528,
#    'lon': -70.04472,
#    'nom': 'CANAL UCHUSUMA'},
#   {'cate': 'CO',
#    'cod': '117043',
#    'cod_old': '158328',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.525,
#    'lon': -69.77944,
#    'nom': 'PAUCARANI'},
#   {'cate': 'CO',
#    'cod': '116052',
#    'cod_old': '158309',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -16.875,
#    'lon': -70.42361,
#    'nom': 'PAMPA UMALZO (TITIJONES)'},
#   {'cate': 'CO',
#    'cod': '117030',
#    'cod_old': '158313',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.28806,
#    'lon': -70.33889,
#    'nom': 'CAIRANI'},
#   {'cate': 'CO',
#    'cod': '117054',
#    'cod_old': '117054',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.32561,
#    'lon': -70.23536,
#    'nom': 'ARICOTA'},
#   {'cate': 'CO',
#    'cod': '117010',
#    'cod_old': '000853',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.60972,
#    'lon': -70.76222,
#    'nom': 'LOCUMBA'},
#   {'cate': 'HLM',
#    'cod': '270900',
#    'cod_old': '211706',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -17.36389,
#    'lon': -69.635,
#    'nom': 'CHUAPALCA'},
#   {'cate': 'CO',
#    'cod': '117049',
#    'cod_old': '158332',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.39359,
#    'lon': -69.46759,
#    'nom': 'LA FRONTERA'},
#   {'cate': 'CO',
#    'cod': '117013',
#    'cod_old': '000860',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.305,
#    'lon': -69.64361,
#    'nom': 'CHUAPALCA'},
#   {'cate': 'PE',
#    'cod': '117039',
#    'cod_old': '158323',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.55917,
#    'lon': -69.99972,
#    'nom': 'TALABAYA'},
#   {'cate': 'PLU',
#    'cod': '117034',
#    'cod_old': '158318',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.3725,
#    'lon': -70.13556,
#    'nom': 'SITAJARA'},
#   {'cate': 'CO',
#    'cod': '117014',
#    'cod_old': '000861',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.1175,
#    'lon': -70.05083,
#    'nom': 'VILACOTA'},
#   {'cate': 'HLM',
#    'cod': '211705',
#    'cod_old': '211707',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -17.11978,
#    'lon': -70.05653,
#    'nom': 'VILACOTA'},
#   {'cate': 'CO',
#    'cod': '117033',
#    'cod_old': '158317',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -17.351,
#    'lon': -70.13333,
#    'nom': 'SUSAPAYA'},
#   {'cate': 'CO',
#    'cod': '103043',
#    'cod_old': '000139',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.97594,
#    'lon': -80.40182,
#    'nom': 'CABO INGA'},
#   {'cate': 'PLU',
#    'cod': '103008',
#    'cod_old': '150112',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -3.68284,
#    'lon': -80.19859,
#    'nom': 'MATAPALO'},
#   {'cate': 'CP',
#    'cod': '108021',
#    'cod_old': '000449',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -8.41323,
#    'lon': -74.57185,
#    'nom': 'PUCALLPA'},
#   {'cate': 'CO',
#    'cod': '109090',
#    'cod_old': '109090',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -8.5825,
#    'lon': -74.86611,
#    'nom': 'EL BOQUERON'},
#   {'cate': 'CP',
#    'cod': '108027',
#    'cod_old': '000459',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -8.44999,
#    'lon': -75.09675,
#    'nom': 'EL MARONAL'},
#   {'cate': 'PLU',
#    'cod': '113153',
#    'cod_old': '156132',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.63972,
#    'lon': -75.71889,
#    'nom': 'LETRAYOC'},
#   {'cate': 'CO',
#    'cod': '113009',
#    'cod_old': '000639',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -13.60118,
#    'lon': -75.62102,
#    'nom': 'HUANCANO'},
#   {'cate': 'CO',
#    'cod': '111174',
#    'cod_old': '111174',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.92745,
#    'lon': -75.11625,
#    'nom': 'ACOPALCA'},
#   {'cate': 'PLU',
#    'cod': '112263',
#    'cod_old': '112263',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -12.04806,
#    'lon': -75.24194,
#    'nom': 'PUENTE BREÑA'},
#   {'cate': 'PLU',
#    'cod': '110133',
#    'cod_old': '155421',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -10.94917,
#    'lon': -74.83056,
#    'nom': 'PERENE'},
#   {'cate': 'HLG',
#    'cod': '230930',
#    'cod_old': '230938',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -10.94944,
#    'lon': -74.83083,
#    'nom': 'PERENE'},
#   {'cate': 'PLU',
#    'cod': '111281',
#    'cod_old': '111281',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.20139,
#    'lon': -75.34606,
#    'nom': 'RIO TULUMAYO'},
#   {'cate': 'CO',
#    'cod': '111039',
#    'cod_old': '000572',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.13361,
#    'lon': -74.25028,
#    'nom': 'PUERTO OCOPA'},
#   {'cate': 'PLU',
#    'cod': '111070',
#    'cod_old': '155115',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.20267,
#    'lon': -76.28505,
#    'nom': 'CARHUACAYAN'},
#   {'cate': 'HLM',
#    'cod': '230801',
#    'cod_old': '230902',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -11.1865,
#    'lon': -76.32569,
#    'nom': 'RIO PALLANGA'},
#   {'cate': 'HLM',
#    'cod': '230803',
#    'cod_old': '230908',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -11.7,
#    'lon': -76.1,
#    'nom': 'RUMICHACA'},
#   {'cate': 'PLU',
#    'cod': '111099',
#    'cod_old': '155235',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -11.66667,
#    'lon': -76.08333,
#    'nom': 'YAULI'},
#   {'cate': 'PLU',
#    'cod': '108043',
#    'cod_old': '154101',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -8.04229,
#    'lon': -78.48607,
#    'nom': 'JULCAN'},
#   {'cate': 'PLU',
#    'cod': '107059',
#    'cod_old': '153206',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.85021,
#    'lon': -78.75503,
#    'nom': 'SINSICAP'},
#   {'cate': 'CP',
#    'cod': '100136',
#    'cod_old': '000325',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.28005,
#    'lon': -79.4191,
#    'nom': 'TALLA (GUADALUPE)'},
#   {'cate': 'HLM',
#    'cod': '220204',
#    'cod_old': '220204',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -7.9325,
#    'lon': -78.06705,
#    'nom': 'LAGUNA HUANGACOCHA'},
#   {'cate': 'PLU',
#    'cod': '107092',
#    'cod_old': '153327',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -7.93761,
#    'lon': -78.06811,
#    'nom': 'HUANGACOCHA'},
#   {'cate': 'PE',
#    'cod': '108046',
#    'cod_old': '154106',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -8.19137,
#    'lon': -77.95397,
#    'nom': 'MOLLEPATA'},
#   {'cate': 'PE',
#    'cod': '108048',
#    'cod_old': '154112',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -8.12139,
#    'lon': -78.29306,
#    'nom': 'HUACAMARCANGA'},
#   {'cate': 'HLM',
#    'cod': '201717',
#    'cod_old': '201717',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -8.10639,
#    'lon': -78.29111,
#    'nom': 'HUACAMARCANGA'},
#   {'cate': 'PLU',
#    'cod': '108044',
#    'cod_old': '154102',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -8.00422,
#    'lon': -78.30791,
#    'nom': 'QUIRUVILCA'},
#   {'cate': 'CP',
#    'cod': '106049',
#    'cod_old': '000335',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.65493,
#    'lon': -79.4279,
#    'nom': 'TINAJONES'},
#   {'cate': 'HLG',
#    'cod': '201001',
#    'cod_old': '201001',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -6.80359,
#    'lon': -79.28932,
#    'nom': 'BATAN'},
#   {'cate': 'CP',
#    'cod': '106037',
#    'cod_old': '000307',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.23389,
#    'lon': -79.31806,
#    'nom': 'INCAHUASI'},
#   {'cate': 'PLU',
#    'cod': '106060',
#    'cod_old': '153102',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.1313,
#    'lon': -79.4045,
#    'nom': 'CUEVA BLANCA'},
#   {'cate': 'CO',
#    'cod': '106120',
#    'cod_old': '003114',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -6.37361,
#    'lon': -79.46951,
#    'nom': 'PUCHACA'},
#   {'cate': 'HLG',
#    'cod': '200801',
#    'cod_old': '200802',
#    'estado': 'DIFERIDO',
#    'ico': 'H',
#    'lat': -6.37317,
#    'lon': -79.46697,
#    'nom': 'PUCHACA'},
#   {'cate': 'CO',
#    'cod': '105122',
#    'cod_old': '105122',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.92461,
#    'lon': -80.20463,
#    'nom': 'CERRO DE ARENA'},
#   {'cate': 'CO',
#    'cod': '105121',
#    'cod_old': '105121',
#    'estado': 'DIFERIDO',
#    'ico': 'M',
#    'lat': -5.91744,
#    'lon': -79.97172,
#    'nom': 'PASAJE SUR'},
#   {'cate': 'CO',
#    'cod': '106057',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -6.37964,
#    'lon': -78.80512,
#    'nom': 'CUTERVO'},
#   {'cate': 'HLG',
#    'cod': '221106',
#    'estado': 'REAL',
#    'ico': 'H',
#    'lat': -6.68656,
#    'lon': -78.51823,
#    'nom': 'LLAUCANO CORELLAMA'},
#   {'cate': 'CP',
#    'cod': '100015',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -6.67655,
#    'lon': -78.51834,
#    'nom': 'BAMBAMARCA'},
#   {'cate': 'CP',
#    'cod': '105067',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -5.67664,
#    'lon': -78.77416,
#    'nom': 'JAEN'},
#   {'cate': 'CO',
#    'cod': '105058',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -5.14708,
#    'lon': -78.99512,
#    'nom': 'SAN IGNACIO'},
#   {'cate': 'CO',
#    'cod': '105074',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -5.3085,
#    'lon': -78.89759,
#    'nom': 'CHIRINOS'},
#   {'cate': 'CO',
#    'cod': '105107',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -4.99953,
#    'lon': -79.08862,
#    'nom': 'NAMBALLE'},
#   {'cate': 'CO',
#    'cod': '105056',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -5.31523,
#    'lon': -79.28492,
#    'nom': 'TABACONAS'},
#   {'cate': 'CO',
#    'cod': '107006',
#    'estado': 'REAL',
#    'ico': 'M',
#    'lat': -7.32249,
#    'lon': -78.1727,
#    'nom': 'SAN MARCOS'},
#   {'cate': 'CO',
#    'cod': '107038',
#    'estado': 'REAL',
#    'ico': 'M',
# ...
#    'nom': 'CHIPILLICO'},
#   {'cate': 'EHA',
#    'cod': '47E0522C',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -4.93848,
#    'lon': -80.34703,
#    'nom': 'TAMBO GRANDE'},
#   {'cate': 'EMA',
#    'cod': '47E281B0',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -4.74767,
#    'lon': -79.61317,
#    'nom': 'HUALCUY'},
#   {'cate': 'EMA',
#    'cod': '472606FA',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -4.63776,
#    'lon': -79.71077,
#    'nom': 'AYABACA'},
#   {'cate': 'EMA',
#    'cod': '472FC5B8',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -4.63439,
#    'lon': -79.94584,
#    'nom': 'PAIMAS'},
#   {'cate': 'EMA',
#    'cod': '472FF022',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -4.79639,
#    'lon': -79.99972,
#    'nom': 'SAPILLICA'},
#   {'cate': 'EHA',
#    'cod': '47E9177A',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -4.29905,
#    'lon': -80.16704,
#    'nom': 'EL CIRUELO - ANA'},
#   {'cate': 'EHA',
#    'cod': '47E0C74E',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -4.39338,
#    'lon': -79.96412,
#    'nom': 'PUENTE MACARA'},
#   {'cate': 'EHMA',
#    'cod': '4724B080',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -4.29909,
#    'lon': -80.16707,
#    'nom': 'EL CIRUELO'},
#   {'cate': 'EMA',
#    'cod': '472FE354',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.24681,
#    'lon': -79.45399,
#    'nom': 'HUANCABAMBA'},
#   {'cate': 'EMA',
#    'cod': '472761E6',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.56599,
#    'lon': -79.52542,
#    'nom': 'HUARMACA'},
#   {'cate': 'EMA',
#    'cod': '472F86B2',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.40058,
#    'lon': -79.60535,
#    'nom': 'CANCHAQUE'},
#   {'cate': 'EHA',
#    'cod': '47E0415A',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -5.1128,
#    'lon': -80.17296,
#    'nom': 'PUENTE ÑACARA'},
#   {'cate': 'EMA',
#    'cod': '472F6540',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.10844,
#    'lon': -80.16954,
#    'nom': 'CHULUCANAS'},
#   {'cate': 'EMA',
#    'cod': '472FB328',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.03389,
#    'lon': -79.83,
#    'nom': 'CHALACO'},
#   {'cate': 'EHA',
#    'cod': '47E08444',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -5.07954,
#    'lon': -80.0162,
#    'nom': 'SAN PEDRO'},
#   {'cate': 'EMA',
#    'cod': '472F7636',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.19465,
#    'lon': -79.97107,
#    'nom': 'MORROPON'},
#   {'cate': 'EMA',
#    'cod': '472F95C4',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.34588,
#    'lon': -79.83794,
#    'nom': 'SALITRAL'},
#   {'cate': 'EHA',
#    'cod': '47E067B6',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -5.34602,
#    'lon': -79.83761,
#    'nom': 'SALITRAL EHA'},
#   {'cate': 'EMA',
#    'cod': '472FA05E',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.33977,
#    'lon': -79.85794,
#    'nom': 'MALACASI'},
#   {'cate': 'EHA',
#    'cod': '47E074C0',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -5.28985,
#    'lon': -79.69924,
#    'nom': 'HACIENDA BARRIOS'},
#   {'cate': 'EHA',
#    'cod': '47E0B1DE',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -4.87999,
#    'lon': -81.02038,
#    'nom': 'PUENTE SIMON RODRIGUEZ'},
#   {'cate': 'EMA',
#    'cod': '472FD6CE',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -4.64288,
#    'lon': -80.54717,
#    'nom': 'LANCONES'},
#   {'cate': 'EHA',
#    'cod': '47E0D438',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -4.48047,
#    'lon': -80.39788,
#    'nom': 'ALAMOR'},
#   {'cate': 'EHA',
#    'cod': '47E09732',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -4.48956,
#    'lon': -80.39014,
#    'nom': 'LA ARDILLA'},
#   {'cate': 'EMA',
#    'cod': '472DD33A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -15.82625,
#    'lon': -70.01208,
#    'nom': 'PUNO'},
#   {'cate': 'EMA',
#    'cod': '472E4156',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -15.68333,
#    'lon': -70.08333,
#    'nom': 'ILLPA'},
#   {'cate': 'EMA',
#    'cod': '472CB426',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -16.13592,
#    'lon': -70.04589,
#    'nom': 'LARAQUERI'},
#   {'cate': 'EAMA',
#    'cod': '4721B992',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -13.88492,
#    'lon': -70.08281,
#    'nom': 'UPINA'},
#   {'cate': 'EAMA',
#    'cod': '4721AAE4',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -13.87279,
#    'lon': -70.66759,
#    'nom': 'AYMAÃ±A'},
#   {'cate': 'EHMA',
#    'cod': '472E112A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -16.08825,
#    'lon': -69.62592,
#    'nom': 'ILAVE'},
#   {'cate': 'EHA',
#    'cod': '47251282',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -15.25544,
#    'lon': -69.87381,
#    'nom': 'PUENTE CARRETERA'},
#   {'cate': 'EMA',
#    'cod': '472DE6A0',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -15.48528,
#    'lon': -70.67578,
#    'nom': 'PAMPAHUTA'},
#   {'cate': 'EHMA',
#    'cod': '472E8448',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -15.74562,
#    'lon': -70.6775,
#    'nom': 'LAGUNILLAS'},
#   {'cate': 'EMA',
#    'cod': '47E3903C',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -15.76448,
#    'lon': -70.911,
#    'nom': 'CRUCERO ALTO'},
#   {'cate': 'EMA',
#    'cod': '472E37C6',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -15.23587,
#    'lon': -70.59315,
#    'nom': 'PALCA'},
#   {'cate': 'EMA',
#    'cod': '472CF72C',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -15.47106,
#    'lon': -70.17122,
#    'nom': 'JULIACA'},
#   {'cate': 'EHA',
#    'cod': '210006',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -6.41291,
#    'lon': -76.60001,
#    'nom': 'SHANAO'},
#   {'cate': 'EHA',
#    'cod': '212600',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -7.26861,
#    'lon': -76.73694,
#    'nom': 'HUAYABAMBA'},
#   {'cate': 'EMA',
#    'cod': '4724851A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.80997,
#    'lon': -77.39328,
#    'nom': 'NARANJILLO'},
#   {'cate': 'EMA',
#    'cod': '4723013A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -6.58923,
#    'lon': -76.31834,
#    'nom': 'EL PORVENIR'},
#   {'cate': 'EHMA',
#    'cod': '47E2E456',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -8.18111,
#    'lon': -76.50556,
#    'nom': 'TOCACHE'},
#   {'cate': 'EMA',
#    'cod': '118014',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -18.03242,
#    'lon': -70.26769,
#    'nom': 'TACNA'},
#   {'cate': 'EHA',
#    'cod': '47E13530',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.96844,
#    'lon': -70.15224,
#    'nom': 'CERRO BLANCO'},
#   {'cate': 'EHA',
#    'cod': '47E1A052',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.63312,
#    'lon': -70.45456,
#    'nom': 'CORUCA'},
#   {'cate': 'EHA',
#    'cod': '4722F344',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.74313,
#    'lon': -70.47178,
#    'nom': 'LA TRANCA PSI'},
#   {'cate': 'EHA',
#    'cod': '47E143A0',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.69071,
#    'lon': -69.91656,
#    'nom': 'CAPLINA'},
#   {'cate': 'EHA',
#    'cod': '47E195C8',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.8151,
#    'lon': -70.09888,
#    'nom': 'CHALLATA'},
#   {'cate': 'EHA',
#    'cod': '47E113DC',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.53886,
#    'lon': -69.76485,
#    'nom': 'REPRESA PAUCARANI'},
#   {'cate': 'EMA',
#    'cod': '47E2B42A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -17.57994,
#    'lon': -69.62672,
#    'nom': 'BOCATOMA EL AYRO'},
#   {'cate': 'EMA',
#    'cod': '47E2C2BA',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -17.26708,
#    'lon': -70.25519,
#    'nom': 'CANDARAVE'},
#   {'cate': 'EHA',
#    'cod': '47E1654C',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.11413,
#    'lon': -70.28831,
#    'nom': 'CORACHAY II'},
#   {'cate': 'EHA',
#    'cod': '47E12646',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -17.37072,
#    'lon': -70.30828,
#    'nom': 'LAGUNA ARICOTA'},
#   {'cate': 'EHA',
#    'cod': '214800',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.47659,
#    'lon': -70.54263,
#    'nom': 'TICAPAMPA PSI'},
#   {'cate': 'EMA',
#    'cod': '47E2D1CC',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -17.4791,
#    'lon': -70.03641,
#    'nom': 'TARATA'},
#   {'cate': 'EMA',
#    'cod': '47E292C6',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -17.30847,
#    'lon': -69.66186,
#    'nom': 'CHUAPALCA'},
#   {'cate': 'EHA',
#    'cod': '47E150D6',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.47491,
#    'lon': -70.17213,
#    'nom': 'PUENTE TALAPALCA'},
#   {'cate': 'EHA',
#    'cod': '117059',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.19972,
#    'lon': -69.93917,
#    'nom': 'ANCOAQUE'},
#   {'cate': 'EMA',
#    'cod': '47E2A75C',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -17.0788,
#    'lon': -70.04305,
#    'nom': 'VILACOTA'},
#   {'cate': 'EHA',
#    'cod': '47E1763A',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.23771,
#    'lon': -70.00949,
#    'nom': 'SALIDA TUNEL KOVIRE'},
#   {'cate': 'EHA',
#    'cod': '47E1B324',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -17.3692,
#    'lon': -69.94863,
#    'nom': 'REPRESA JARUMAS'},
#   {'cate': 'EHA',
#    'cod': '47E024BC',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -3.5709,
#    'lon': -80.4609,
#    'nom': 'PUENTE TUMBES'},
#   {'cate': 'EMA',
#    'cod': '472EF2D8',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -3.55117,
#    'lon': -80.42964,
#    'nom': 'CAMPAMENTO SEDE'},
#   {'cate': 'EMA',
#    'cod': '472F264A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -3.81333,
#    'lon': -80.4575,
#    'nom': 'RICA PLAYA'},
#   {'cate': 'EMA',
#    'cod': '472F43AC',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -3.99945,
#    'lon': -80.505,
#    'nom': 'HUASIMO'},
#   {'cate': 'EMA',
#    'cod': '472F00A6',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -3.97594,
#    'lon': -80.40182,
#    'nom': 'CABO INGA'},
#   {'cate': 'EHA',
#    'cod': '47E01126',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -3.97972,
#    'lon': -80.39898,
#    'nom': 'CABO INGA'},
#   {'cate': 'EHMA',
#    'cod': '4724A3F6',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -3.7687,
#    'lon': -80.45689,
#    'nom': 'EL TIGRE'},
#   {'cate': 'EMA',
#    'cod': '472F13D0',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -3.93911,
#    'lon': -80.65058,
#    'nom': 'CAÑAVERAL'},
#   {'cate': 'EMA',
#    'cod': '472F353C',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -3.68278,
#    'lon': -80.19833,
#    'nom': 'MATAPALO'},
#   {'cate': 'EMA',
#    'cod': '47E86310',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.89825,
#    'lon': -74.49886,
#    'nom': 'CALLERIA'},
#   {'cate': 'EMA',
#    'cod': '47E8568A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -8.4984,
#    'lon': -75.5597,
#    'nom': 'SANTA ANA'},
#   {'cate': 'EMA',
#    'cod': '47E87066',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -9.75028,
#    'lon': -70.75028,
#    'nom': 'PUERTO ESPERANZA'},
#   {'cate': 'EHA',
#    'cod': '213403',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -13.65773,
#    'lon': -75.74496,
#    'nom': 'LETRAYOC PSI'},
#   {'cate': 'EMA',
#    'cod': '472DF5D6',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.92667,
#    'lon': -75.06167,
#    'nom': 'HUAYTAPALLANA'},
#   {'cate': 'EMA',
#    'cod': '112273',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.06194,
#    'lon': -75.21306,
#    'nom': 'EL TAMBO'},
#   {'cate': 'EAMA',
#    'cod': '4725C4EA',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.23361,
#    'lon': -74.70028,
#    'nom': 'SATIPO'},
#   {'cate': 'EMA',
#    'cod': '47257764',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.39694,
#    'lon': -75.69028,
#    'nom': 'TARMA'},
#   {'cate': 'EMA',
#    'cod': '111288',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.7328,
#    'lon': -75.7557,
#    'nom': 'CHACAPALPA'},
#   {'cate': 'EMA',
#    'cod': '472D9030',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.40443,
#    'lon': -76.32508,
#    'nom': 'MARCAPOMACOCHA'},
#   {'cate': 'EMA',
#    'cod': '107131',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.67042,
#    'lon': -78.40242,
#    'nom': 'LA FORTUNA'},
#   {'cate': 'EMA',
#    'cod': '472D60B4',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.8186,
#    'lon': -78.41497,
#    'nom': 'USQUIL'},
#   {'cate': 'EHMA',
#    'cod': '472E74CC',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.79636,
#    'lon': -78.38012,
#    'nom': 'PUENTE COINA'},
#   {'cate': 'EMA',
#    'cod': '472EB1D2',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.85642,
#    'lon': -78.31184,
#    'nom': 'CAPACHIQUE'},
#   {'cate': 'EAA',
#    'cod': '107130',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.9123,
#    'lon': -77.90148,
#    'nom': 'TICAPAMPA'},
#   {'cate': 'EMA',
#    'cod': '4727319A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -8.00419,
#    'lon': -78.3079,
#    'nom': 'QUIRUVILCA'},
#   {'cate': 'EHMA',
#    'cod': '472E5220',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.54919,
#    'lon': -78.81051,
#    'nom': 'PUENTE PALMIRA'},
#   {'cate': 'EMA',
#    'cod': '472EA2A4',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.47987,
#    'lon': -78.82367,
#    'nom': 'CASCAS'},
#   {'cate': 'EHMA',
#    'cod': '47E0A2A8',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.57417,
#    'lon': -78.70694,
#    'nom': 'EL TAMBO'},
#   {'cate': 'EMA',
#    'cod': '472D552E',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.64333,
#    'lon': -78.55135,
#    'nom': 'LUCMA'},
#   {'cate': 'EAMA',
#    'cod': '472CC2B6',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -7.7635,
#    'lon': -78.66725,
#    'nom': 'MARMOT'},
#   {'cate': 'EMA',
#    'cod': '106137',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -6.78192,
#    'lon': -79.84136,
#    'nom': 'CHICLAYO'},
#   {'cate': 'EMA',
#    'cod': '47E2F720',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -6.65489,
#    'lon': -79.42792,
#    'nom': 'TINAJONES'},
#   {'cate': 'EMA',
#    'cod': '47201542',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -6.06692,
#    'lon': -79.68203,
#    'nom': 'MOTUPE'},
#   {'cate': 'EMA',
#    'cod': '472F50DA',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.53579,
#    'lon': -79.98416,
#    'nom': 'EL VIRREY'},
#   {'cate': 'EMA',
#    'cod': '4726F67E',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -5.83714,
#    'lon': -79.81911,
#    'nom': 'OLMOS'},
#   {'cate': 'EMA',
#    'cod': '472A218A',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.77606,
#    'lon': -77.15139,
#    'nom': 'EMA-ANTONIO RAIMONDI'},
#   {'cate': 'EAA',
#    'cod': '00112271',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.02611,
#    'lon': -76.91861,
#    'nom': 'SANTA ANITA'},
#   {'cate': 'EAA',
#    'cod': '112192',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.02611,
#    'lon': -76.91861,
#    'nom': 'ATE'},
#   {'cate': 'EAA',
#    'cod': '111286',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.90219,
#    'lon': -77.03364,
#    'nom': 'CARABAYLLO'},
#   {'cate': 'EAMA',
#    'cod': '112194',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.07053,
#    'lon': -77.04317,
#    'nom': 'CAMPO DE MARTE'},
#   {'cate': 'EMA',
#    'cod': '112181',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.07057,
#    'lon': -77.0432,
#    'nom': 'CAMPO DE MARTE'},
#   {'cate': 'EMA',
#    'cod': '472AC278',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.08221,
#    'lon': -76.93931,
#    'nom': 'VON HUMBOLDT'},
#   {'cate': 'EMA',
#    'cod': '111290',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.98744,
#    'lon': -76.84194,
#    'nom': 'ÑAÑA'},
#   {'cate': 'EHMA',
#    'cod': '47278214',
#    'estado': 'AUTOMATICA',
#    'ico': 'H',
#    'lat': -11.92985,
#    'lon': -76.68973,
#    'nom': 'CHOSICA'},
#   {'cate': 'EMA',
#    'cod': '00112270',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.10863,
#    'lon': -77.00777,
#    'nom': 'SAN BORJA'},
#   {'cate': 'EAA',
#    'cod': '112193',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.10863,
#    'lon': -77.00777,
#    'nom': 'SAN BORJA'},
#   {'cate': 'EAA',
#    'cod': '112266',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -12.01689,
#    'lon': -76.94883,
#    'nom': 'HUACHIPA'},
#   {'cate': 'EAA',
#    'cod': '112267',
#    'estado': 'AUTOMATICA',
#    'ico': 'M',
#    'lat': -11.98164,
#    'lon': -76.99925,
#    'nom': 'SAN JUAN DE LURIGANCHO'}]}

# %%
print('MACHU PICCHU:', o )
# Out:
# MACHU PICCHU: {'estaciones': [{'nom': 'MONTE GRANDE', 'cate': 'CO', 'lat': -7.22499, 'lon': -79.15323, 'ico': 'M', 'cod': '100090', 'cod_old': '000396', 'estado': 'DIFERIDO'}, {'nom': 'QUEROCOTILLO', 'cate': 'PLU', 'lat': -6.27366, 'lon': -79.03696, 'ico': 'M', 'cod': '106067', 'cod_old': '153109', 'estado': 'DIFERIDO'}, {'nom': 'PUENTE  MAYGASBAMBA', 'cate': 'HLG', 'lat': -6.67411, 'lon': -78.52437, 'ico': 'H', 'cod': '221110', 'cod_old': '220307', 'estado': 'DIFERIDO'}, {'nom': 'QUEBRADA SHUGAR', 'cate': 'PLU', 'lat': -6.68778, 'lon': -78.45694, 'ico': 'M', 'cod': '100113', 'cod_old': '153108', 'estado': 'DIFERIDO'}, {'nom': 'CHUGUR', 'cate': 'PLU', 'lat': -6.67091, 'lon': -78.73717, 'ico': 'M', 'cod': '106077', 'cod_old': '153208', 'estado': 'DIFERIDO'}, {'nom': 'LA CASCARILLA', 'cate': 'CO', 'lat': -5.67175, 'lon': -78.89767, 'ico': 'M', 'cod': '105062', 'cod_old': '000349', 'estado': 'DIFERIDO'}, {'nom': 'CHONTALI', 'cate': 'CO', 'lat': -5.64389, 'lon': -79.09, 'ico': 'M', 'cod': '105065', 'cod_old': '000250', 'estado': 'DIFERIDO'}, {'nom': 'PUENTE CHUNCHUCA', 'cate': 'PLU', 'lat': -5.94222, 'lon': -78.85639, 'ico': 'M', 'cod': '105110', 'cod_old': '152213', 'estado': 'DIFERIDO'}, {'nom': 'CACAO', 'cate': 'HLM', 'lat': -5.91694, 'lon': -78.95028, 'ico': 'H', 'cod': '220405', 'cod_old': '220405', 'estado': 'DIFERIDO'}, {'nom': 'EL LIMON', 'cate': 'CO', 'lat': -5.91778, 'lon': -79.31722, 'ico': 'M', 'cod': '105057', 'cod_old': '000241', 'estado': 'DIFERIDO'}, {'nom': 'HACIENDA PUCARA', 'cate': 'PLU', 'lat': -6.04167, 'lon': -79.13389, 'ico': 'M', 'cod': '106065', 'cod_old': '153107', 'estado': 'DIFERIDO'}, {'nom': 'SALLIQUE', 'cate': 'CO', 'lat': -5.65889, 'lon': -79.3125, 'ico': 'M', 'cod': '105053', 'cod_old': '002129', 'estado': 'DIFERIDO'}, {'nom': 'COCHALAN', 'cate': 'PLU', 'lat': -5.46639, 'lon': -78.98861, 'ico': 'M', 'cod': '105111', 'cod_old': '152212', 'estado': 'DIFERIDO'}, {'nom': 'COCHALAN', 'cate': 'HLG', 'lat': -5.46506, 'lon': -78.98822, 'ico': 'H', 'cod': '220814', 'cod_old': '220815', 'estado': 'DIFERIDO'}, {'nom': 'TABACONAS', 'cate': 'HLG', 'lat': -5.32221, 'lon': -79.28779, 'ico': 'H', 'cod': '220812', 'cod_old': '220813', 'estado': 'DIFERIDO'}, {'nom': 'LIVES', 'cate': 'PLU', 'lat': -7.0802, 'lon': -79.04045, 'ico': 'M', 'cod': '107055', 'cod_old': '153111', 'estado': 'DIFERIDO'}, {'nom': 'CHANCAY BAÑOS', 'cate': 'CO', 'lat': -6.575, 'lon': -78.86722, 'ico': 'M', 'cod': '106022', 'cod_old': '000395', 'estado': 'DIFERIDO'}, {'nom': 'CIRATO', 'cate': 'HLG', 'lat': -6.65579, 'lon': -79.07395, 'ico': 'H', 'cod': '106122', 'cod_old': '200909', 'estado': 'DIFERIDO'}, {'nom': 'SALCCA', 'cate': 'PE', 'lat': -14.16997, 'lon': -71.23187, 'ico': 'M', 'cod': '114131', 'cod_old': '114131', 'estado': 'DIFERIDO'}, {'nom': 'YAURI', 'cate': 'CO', 'lat': -14.81694, 'lon': -71.41694, 'ico': 'M', 'cod': '114032', 'cod_old': '000757', 'estado': 'DIFERIDO'}, {'nom': 'CHACLLABAMBA', 'cate': 'CO', 'lat': -13.10855, 'lon': -71.72, 'ico': 'M', 'cod': '113139', 'cod_old': '155518', 'estado': 'DIFERIDO'}, {'nom': 'CHONTACHACA', 'cate': 'CO', 'lat': -13.02389, 'lon': -71.46778, 'ico': 'M', 'cod': '100030', 'cod_old': '006671', 'estado': 'DIFERIDO'}, {'nom': 'HUANCALPI', 'cate': 'CO', 'lat': -12.53944, 'lon': -75.23667, 'ico': 'M', 'cod': '112142', 'cod_old': '156126', 'estado': 'DIFERIDO'}, {'nom': 'HUACHOS', 'cate': 'CO', 'lat': -13.2206, 'lon': -75.53348, 'ico': 'M', 'cod': '113067', 'cod_old': '151503', 'estado': 'DIFERIDO'}, {'nom': 'SAN JUAN DE CASTROVIRREYNA', 'cate': 'CO', 'lat': -13.21198, 'lon': -75.62758, 'ico': 'M', 'cod': '113082', 'cod_old': '156114', 'estado': 'DIFERIDO'}, {'nom': 'CHOCLOCOCHA', 'cate': 'CO', 'lat': -13.1588, 'lon': -75.07145, 'ico': 'M', 'cod': '113091', 'cod_old': '156130', 'estado': 'DIFERIDO'}, {'nom': 'PAUCARBAMBA', 'cate': 'CO', 'lat': -12.46667, 'lon': -74.56667, 'ico': 'M', 'cod': '112066', 'cod_old': '000658', 'estado': 'DIFERIDO'}, {'nom': 'CORDOVA', 'cate': 'PLU', 'lat': -14.04061, 'lon':  ...

# %%
print ()
